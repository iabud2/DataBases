# %%
import csv, sqlite3
import pandas

# %%
conn = sqlite3.connect('RealWorldData.db')

# %%
# %load_ext sql

# %%
# %sql sqlite:///RealWorldData.db

# %%
# %sql select name from sqlite_master where type='table'
# Out:
#  * sqlite:///RealWorldData.db
# Done.
# [('CHICAGO_PUBLIC_SCHOOLS_DATA',), ('CENSUS_DATA',)]

# %%
# %sql select hardship_index from CENSUS_DATA CD , CHICAGO_PUBLIC_SCHOOLS_DATA CPS\
WHERE CD.community_area_name = CPS.community_area_name
# Out:
#  * sqlite:///RealWorldData.db
# Done.
# []

# %%
# %%sql
# select hardship_index CD1 from CENSUS_DATA CD, CHICAGO_PUBLIC_SCHOOLS_DATA CPS
# where CD.community_area_name = CPS.COMMUNITY_AREA_NAME and college_enrollment
# and college_enrollment = 4368
# Out:
#  * sqlite:///RealWorldData.db
# Done.
# []

# %%
# %%sql
# select hardship_index , CPS.COMMUNITY_AREA_NAME from CENSUS_DATA CD , CHICAGO_PUBLIC_SCHOOLS_DATA CPS
# WHERE CPS.COLLEGE_ENROLLMENT = (SELECT MAX(COLLEGE_ENROLLMENT) FROM CHICAGO_PUBLIC_SCHOOLS_DATA)
# Out:
#  * sqlite:///RealWorldData.db
# Done.
# [(39.0, 'NORTH CENTER'),
#  (46.0, 'NORTH CENTER'),
#  (20.0, 'NORTH CENTER'),
#  (17.0, 'NORTH CENTER'),
#  (6.0, 'NORTH CENTER'),
#  (5.0, 'NORTH CENTER'),
#  (2.0, 'NORTH CENTER'),
#  (1.0, 'NORTH CENTER'),
#  (8.0, 'NORTH CENTER'),
#  (21.0, 'NORTH CENTER'),
#  (25.0, 'NORTH CENTER'),
#  (11.0, 'NORTH CENTER'),
#  (33.0, 'NORTH CENTER'),
#  (53.0, 'NORTH CENTER'),
#  (35.0, 'NORTH CENTER'),
#  (34.0, 'NORTH CENTER'),
#  (28.0, 'NORTH CENTER'),
#  (50.0, 'NORTH CENTER'),
#  (70.0, 'NORTH CENTER'),
#  (71.0, 'NORTH CENTER'),
#  (42.0, 'NORTH CENTER'),
#  (23.0, 'NORTH CENTER'),
#  (85.0, 'NORTH CENTER'),
#  (10.0, 'NORTH CENTER'),
#  (73.0, 'NORTH CENTER'),
#  (92.0, 'NORTH CENTER'),
#  (83.0, 'NORTH CENTER'),
#  (15.0, 'NORTH CENTER'),
#  (87.0, 'NORTH CENTER'),
#  (96.0, 'NORTH CENTER'),
#  (76.0, 'NORTH CENTER'),
#  (3.0, 'NORTH CENTER'),
#  (7.0, 'NORTH CENTER'),
#  (82.0, 'NORTH CENTER'),
#  (47.0, 'NORTH CENTER'),
# ...

# %%
# %sql select  community_area_name, hardship_index from CENSUS_DATA \
   where community_area_name in \
   ( select community_area_name from CHICAGO_PUBLIC_SCHOOLS_DATA order by college_enrollment desc limit 1 )
# Out:
#  * sqlite:///RealWorldData.db
# Done.
# []
